# %%
# import libraries
import pandas as pd 
import folium
import numpy as np
import json

# %% [markdown]
# Dataset link: https://exceljet.net/download-coronavirus-data-to-excel
# geojson github repo:https://github.com/johan/world.geo.json

# %%
# read the excel file 
df=pd.read_excel(r'C:\Users\prajw\Downloads\covid-19 world eudata.xlsx')
df
# Out:
#       Unnamed: 0                    Unnamed: 1           Unnamed: 2  \
# 0            NaN  Worldwide Corona Virus Cases                  NaN
# 1            NaN                           NaN                  NaN
# 2            NaN       countriesAndTerritories              dateRep
# 3            NaN                   Afghanistan  2020-04-02 00:00:00
# 4            NaN                   Afghanistan  2020-04-01 00:00:00
# ...          ...                           ...                  ...
# 8302         NaN                      Zimbabwe  2020-03-25 00:00:00
# 8303         NaN                      Zimbabwe  2020-03-24 00:00:00
# 8304         NaN                      Zimbabwe  2020-03-23 00:00:00
# 8305         NaN                      Zimbabwe  2020-03-22 00:00:00
# 8306         NaN                      Zimbabwe  2020-03-21 00:00:00
#
#      Unnamed: 3 Unnamed: 4                             Unnamed: 5  Unnamed: 6  \
# ...

# %%
# check the info of the dataframe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8307 entries, 0 to 8306
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  8306 non-null   object
#  2   Unnamed: 2  8305 non-null   object
#  3   Unnamed: 3  8305 non-null   object
#  4   Unnamed: 4  8305 non-null   object
#  5   Unnamed: 5  8284 non-null   object
#  6   Unnamed: 6  0 non-null      float64
#  7   Unnamed: 7  4 non-null      object
#  8   Unnamed: 8  4 non-null      object
# dtypes: float64(2), object(7)
# memory usage: 584.2+ KB

# %%
# drop the first two rows and unwanted columns
df.drop(df.head(3).index, inplace=True)
df.drop(['Unnamed: 0','Unnamed: 2','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8'],axis=1,inplace=True)

# %%
df
# Out:
#        Unnamed: 1 Unnamed: 3 Unnamed: 4
# 3     Afghanistan         26          0
# 4     Afghanistan         25          0
# 5     Afghanistan         27          0
# 6     Afghanistan          8          1
# 7     Afghanistan         15          1
# ...           ...        ...        ...
# 8302     Zimbabwe          0          0
# 8303     Zimbabwe          0          1
# 8304     Zimbabwe          0          0
# 8305     Zimbabwe          1          0
# 8306     Zimbabwe          1          0
#
# [8304 rows x 3 columns]

# %%
# rename the columns 
df.columns=['country','cases','deaths']

# %%
df
# Out:
#           country cases deaths
# 3     Afghanistan    26      0
# 4     Afghanistan    25      0
# 5     Afghanistan    27      0
# 6     Afghanistan     8      1
# 7     Afghanistan    15      1
# ...           ...   ...    ...
# 8302     Zimbabwe     0      0
# 8303     Zimbabwe     0      1
# 8304     Zimbabwe     0      0
# 8305     Zimbabwe     1      0
# 8306     Zimbabwe     1      0
#
# [8304 rows x 3 columns]

# %%
# grouping based on the country
g=df.groupby('country').sum()
g
# Out:
#              cases  deaths
# country
# Afghanistan    192       4
# Albania        259      15
# Algeria        847      58
# Andorra        390      14
# Angola           8       2
# ...            ...     ...
# Uzbekistan     187       2
# Venezuela      143       3
# Vietnam        235       0
# Zambia          36       0
# Zimbabwe         8       1
#
# [204 rows x 2 columns]

# %%
# store the country index because after we reset the index the country index will be deleted 
col=g.index
col
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua_and_Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        ...
#        'United_Kingdom', 'United_Republic_of_Tanzania',
#        'United_States_Virgin_Islands', 'United_States_of_America', 'Uruguay',
#        'Uzbekistan', 'Venezuela', 'Vietnam', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='country', length=204)

# %%
# set the new index using np.arange
g=g.set_index(keys=np.arange(g.shape[0]))
g
# Out:
#      cases  deaths
# 0      192       4
# 1      259      15
# 2      847      58
# 3      390      14
# 4        8       2
# ..     ...     ...
# 199    187       2
# 200    143       3
# 201    235       0
# 202     36       0
# 203      8       1
#
# [204 rows x 2 columns]

# %%
# the stored values are added as a column 
g.insert(loc=0, column='country', value=col)
g
# Out:
#          country  cases  deaths
# 0    Afghanistan    192       4
# 1        Albania    259      15
# 2        Algeria    847      58
# 3        Andorra    390      14
# 4         Angola      8       2
# ..           ...    ...     ...
# 199   Uzbekistan    187       2
# 200    Venezuela    143       3
# 201      Vietnam    235       0
# 202       Zambia     36       0
# 203     Zimbabwe      8       1
#
# [204 rows x 3 columns]

# %%
# we format the country column 
g['country']=g['country'].str.replace('_',' ')

# %%
g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 204 entries, 0 to 203
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  204 non-null    object
#  1   cases    204 non-null    int64
#  2   deaths   204 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 6.4+ KB

# %%
# cretae a foluim object 
world_map=folium.Map(zoom_state=1,tiles='Mapbox Bright')
# json file path
world_geojson_path=r'C:\Users\prajw\Downloads\world-countries.json'
with open(world_geojson_path, 'r') as j:
     jcont = json.loads(j.read())

# %%
jcont
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Afghanistan'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[61.210817, 35.650072],
#       [62.230651, 35.270664],
#       [62.984662, 35.404041],
#       [63.193538, 35.857166],
#       [63.982896, 36.007957],
#       [64.546479, 36.312073],
#       [64.746105, 37.111818],
#       [65.588948, 37.305217],
#       [65.745631, 37.661164],
#       [66.217385, 37.39379],
#       [66.518607, 37.362784],
#       [67.075782, 37.356144],
#       [67.83, 37.144994],
#       [68.135562, 37.023115],
#       [68.859446, 37.344336],
#       [69.196273, 37.151144],
#       [69.518785, 37.608997],
#       [70.116578, 37.588223],
#       [70.270574, 37.735165],
#       [70.376304, 38.138396],
#       [70.806821, 38.486282],
#       [71.348131, 38.258905],
#       [71.239404, 37.953265],
#       [71.541918, 37.905774],
#       [71.448693, 37.065645],
#       [71.844638, 36.738171],
# ...

# %%
country_names=[]
# to exctract all the countries name from the geojson file 
for i in range(len(jcont['features'])):
    l=jcont['features'][i]['properties']['name']
    country_names.append(l)

# %%
# countires that are not in geojson 
d = g[~g['country'].isin(country_names)]
print("Total No countries in the dataset which are not in the geojson are", d.shape[0])
# Out:
# Total No countries in the dataset which are not in the geojson are 50

# %%
# passing paramters to Choropleth 
folium.Choropleth(
          geo_data=world_geojson_path,
          data=g,
          columns=['country','cases'],
          key_on='feature.properties.name',
          fill_color= 'YlOrRd',
          nan_fill_color='white',
          bins=np.linspace(0,g['cases'].max(),num=5),
          legend_name='Covid 19 Confirmed Cases'
).add_to(world_map)
# to show the graph 
world_map
# most of the countries have be in the same range so there is a bit bias in the plotted map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
